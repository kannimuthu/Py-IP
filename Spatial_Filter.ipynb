# %%
#Mean Filter
import cv2
import numpy as np
import scipy.ndimage
import matplotlib.pyplot as plt
# Opening the image using cv2.
a = cv2.imread('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/ultrasound_muscle.png')
# Converting the image to grayscale.
a = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
# Initializing the filter of size 5 by 5.
# The filter is divided by 25 for normalization.
k = np.ones((5,5))/25
# performing convolution
b = scipy.ndimage.filters.convolve(a, k)
# Writing b to a file.
cv2.imwrite('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/mean_output.png', b)
plt.imshow(b)
plt.show()

# %%
#Median Filter
import cv2
import scipy.ndimage

# Opening the image and converting it to grayscale.
a = cv2.imread('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/ct_saltandpepper.png')
# Converting the image to grayscale.
a = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
# Performing the median filter.
b = scipy.ndimage.filters.median_filter(a, size=5)
# Saving b as median_output.png in Figures folder
cv2.imwrite('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/median1_output.png', b)
# Out:
# True

# %%
#Min
import cv2
import scipy.ndimage

# opening the image and converting it to grayscale
a = cv2.imread('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/wave.png')

# performing minimum filter
b = scipy.ndimage.filters.minimum_filter(a, size=5)
# saving b as mino.png
cv2.imwrite('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/mino.png', b)
# Out:
# True

# %%
#Max
import cv2
import scipy.ndimage

# opening the image and converting it to grayscale
image = cv2.imread('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/wave.png')
ga=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imwrite('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/waveg.png',ga)
a= cv2.imread('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/waveg.png')
# performing maximum filter
b = scipy.ndimage.filters.maximum_filter(a, size=5)
# b is converted from an ndarray to an image
cv2.imwrite('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/maxo.png', b)
# Out:
# True

# %%
#Sobel
import cv2
from scipy import ndimage

# Opening the image.
a = cv2.imread('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/cir.png')
# Converting a to grayscale .
a = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
# Performing Sobel filter.
b = ndimage.sobel(a)
# Saving b.
cv2.imwrite('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/sobel_cir.png', b)
# Out:
# True

# %%
# !pip3 install importlib-metadata

# %%
#Vertical Sobel
import cv2
from skimage import filters

# Opening the image.
a = cv2.imread('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/cir.png')
# Converting a to grayscale.
a = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
# Performing vertical Sobel.
b = filters.sobel_v(a)
min_b, max_b = b.min(), b.max()
b = 255*(b-min_b)/(max_b-min_b)
# Saving b.
cv2.imwrite('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/sobel_vcir.png', b)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\fsspec\__init__.py in <module>
#       1 try:
# ----> 2     from importlib.metadata import entry_points
#       3 except ImportError:  # python < 3.8
#
# ModuleNotFoundError: No module named 'importlib.metadata'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-ebed22ecb211> in <module>
#       1 #Vertical Sobel
#       2 import cv2
# ----> 3 from skimage import filters
#       4
#       5 # Opening the image.
#
# ~\Anaconda3\lib\site-packages\skimage\__init__.py in <module>
#     133                              img_as_bool,
#     134                              dtype_limits)
# --> 135     from .data import data_dir
# ...

# %%
#prewitt
import cv2
from scipy import ndimage

# Opening the image.
a = cv2.imread('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/cir.png')
# Converting a to grayscale .
a = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
# Performing Prewitt filter.
b = ndimage.prewitt(a)
min_b, max_b = b.min(), b.max()
b = 255.0*(b-min_b)/(max_b-min_b)
# Saving b.
cv2.imwrite('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/prewitt_cir.png', b)
# Out:
# True

# %%
#prewitt vertical
import cv2
from skimage import filters
import matplotlib.pyplot as plt

# Opening the image.
a = cv2.imread('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/cir.png')
# Converting a to grayscale .
a = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
# Performing vertical Prewitt.
b = filters.prewitt_v(a)
min_b, max_b = b.min(), b.max()
b = 255*(b-min_b)/(max_b-min_b)
# Saving b .
cv2.imwrite('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/prewitt_vcir.png', b)
# Displaying b.
plt.imshow(b, 'gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\fsspec\__init__.py in <module>
#       1 try:
# ----> 2     from importlib.metadata import entry_points
#       3 except ImportError:  # python < 3.8
#
# ModuleNotFoundError: No module named 'importlib.metadata'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-37021c1b9d6f> in <module>
#       1 #prewitt vertical
#       2 import cv2
# ----> 3 from skimage import filters
#       4 import matplotlib.pyplot as plt
#       5
#
# ~\Anaconda3\lib\site-packages\skimage\__init__.py in <module>
#     133                              img_as_bool,
#     134                              dtype_limits)
# --> 135     from .data import data_dir
# ...

# %%
#Laplacian
import cv2
import scipy.ndimage
# Opening the image.
a = cv2.imread('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/imagefor_laplacian.png')
# Performing Laplacian filter.
b = scipy.ndimage.filters.laplace(a,mode='reflect')
cv2.imwrite('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/laplacian_new.png',b)
# Out:
# True

# %%
import cv2
 
# Opening the image.
a = cv2.imread('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/maps1.png')
# Performing Canny edge filter.
b = cv2.Canny(a, 100, 200)
# Saving b.
cv2.imwrite('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/canny_output.png', b)
# Out:
# True

# %%
# Color Conversion
import cv2
# opening the image and converting it to grayscale 
a = cv2.imread('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/cir.png')
a = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)


cv2.imwrite('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/color_ouptu.png', a)
# Out:
# True

# %%
import cv2
import numpy as np

import numpy as np
from PIL import Image
from skimage.filters import frangi

img = cv2.imread('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/angiogram1.png')
img1 = np.asarray(img)
img2 = frangi(img1, black_ridges=True)
img3 = 255*(img2-np.min(img2))/(np.max(img2)-np.min(img2))
cv2.imwrite('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/frangi_output.png', img3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\fsspec\__init__.py in <module>
#       1 try:
# ----> 2     from importlib.metadata import entry_points
#       3 except ImportError:  # python < 3.8
#
# ModuleNotFoundError: No module named 'importlib.metadata'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-8987f993e447> in <module>
#       4 import numpy as np
#       5 from PIL import Image
# ----> 6 from skimage.filters import frangi
#       7
#       8 img = cv2.imread('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/angiogram1.png')
#
# ~\Anaconda3\lib\site-packages\skimage\__init__.py in <module>
#     133                              img_as_bool,
# ...

# %%
import cv2
import scipy.ndimage

# Opening the image.
a = cv2.imread('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/vhuman_t1.png')
# Performing Laplacian of Gaussian.
b = scipy.ndimage.filters.gaussian_laplace(a, sigma=1, mode='reflect')
cv2.imwrite('C:/Users/ROHINI/Desktop/KCE-GL/Python-IP/Demo/Figures/log_vh1.png', b)
# Out:
# True
